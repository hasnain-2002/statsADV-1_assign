# %% [markdown]
# 1)What is a random variable in probability theory?

# %% [markdown]
# A random variable is a numerical value that represents the outcome of a random process. It's a function that maps outcomes of a random experiment to numbers.

# %% [markdown]
# 2)What are the types of random variables?
# 3) What is the difference between discrete and continuous distributions?
#  4)What are probability distribution functions (PDF)?
# 5) How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF

# %% [markdown]
# ANS 2)Discrete Random Variables: Take on countable values (e.g., number of heads in 10 coin tosses).
#
# Continuous Random Variables: Take on values in an interval (e.g., height, weight, time).

# %% [markdown]
# ANS 3)Discrete Distribution: Describes probability of each value of a discrete variable (e.g., Binomial, Poisson).
#
# Continuous Distribution: Describes probability density over a range of values (e.g., Normal, Uniform).

# %% [markdown]
# ANS 4)A PDF (more accurately for continuous variables) defines the likelihood of a random variable taking a particular value or falling within an interval.
#
# For discrete variables, this is called a probability mass function (PMF).

# %% [markdown]
# ANS 5)PDF shows the likelihood of a specific value (for continuous, the density).
#
# CDF (Cumulative Distribution Function) gives the probability that the variable is less than or equal to a certain value.

# %% [markdown]
#  6)What is a discrete uniform distribution?
#  7)What are the key properties of a Bernoulli distribution?
#  8)What is the binomial distribution, and how is it used in probability?
#  9)What is the Poisson distribution and where is it applied?
#  10)What is a continuous uniform distribution?
#  11)What are the characteristics of a normal distribution?
# 12) What is the standard normal distribution, and why is it important?

# %% [markdown]
# ANS 6)A distribution where all outcomes are equally likely.
# Example: Rolling a fair six-sided die — each number (1 to 6) has probability 1/6.

# %% [markdown]
# ANS 7)Only two outcomes: success (1) and failure (0).
#
# Probability of success = p, failure = 1 − p
#
# Used in binary events like yes/no, pass/fail.

# %% [markdown]
# ANS 8)Models the number of successes in n independent Bernoulli trials.
#
# Parameters: n (number of trials), p (probability of success).

# %% [markdown]
# ANS 9)Models the number of events occurring in a fixed interval of time or space.
#
# Used when events occur randomly and independently at a constant rate (e.g., incoming phone calls, traffic accidents).

# %% [markdown]
# ANS 10)A distribution where every value within a given range is equally likely.
# Example: Randomly selecting a number between 0 and 1.

# %% [markdown]
# ANS 11)Characteristics of a Normal Distribution
# Symmetrical bell-shaped curve.
#
# Mean = Median = Mode.
#
# Defined by mean (μ) and standard deviation (σ).

# %% [markdown]
# ANS 12)A normal distribution with μ = 0 and σ = 1.
#
# Used to compare values across different normal distributions via Z-scores.

# %% [markdown]
# 13)What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#  14)How does the Central Limit Theorem relate to the normal distribution?
#  15)What is the application of Z statistics in hypothesis testing?
#  16)How do you calculate a Z-score, and what does it represent?
#  17)What are point estimates and interval estimates in statistics?
# 18) What is the significance of confidence intervals in statistical analysis?
#  19)What is the relationship between a Z-score and a confidence interval?
# 20) How are Z-scores used to compare different distributions?

# %% [markdown]
# ANS 13)CLT states that the sampling distribution of the sample mean approaches a normal distribution as sample size increases, regardless of the population’s distribution.

# %% [markdown]
# ANS 14)It explains why normal distribution appears so often — sample means from various distributions will approximate normality as n increases.

# %% [markdown]
# ANS 15)Z-tests are used when population variance is known and data is normally distributed or sample size is large. It's used to test means and proportions.

# %% [markdown]
# ANS 16)Z=X-MEW/SIGMA
#
# It tells you how many standard deviations a value X is from the mean μ.

# %% [markdown]
# ANS 17) Point Estimates and Interval Estimates
# Point Estimate: A single value (e.g., sample mean) that estimates a population parameter.
#
# Interval Estimate: A range (e.g., confidence interval) that likely contains the parameter.

# %% [markdown]
# ANS 18)Significance of Confidence Intervals
# They provide a range in which we expect the population parameter to lie, with a certain level of confidence (e.g., 95%).

# %% [markdown]
# ANS 19)CI=X(BAR)+-Z*SIGMA/N(ROOT)

# %% [markdown]
# ANS 20)Z-scores standardize different distributions, allowing direct comparison of values from different scales or populations.

# %% [markdown]
#  21)What are the assumptions for applying the Central Limit Theorem
#  22)What is the concept of expected value in a probability distribution
# 23) How does a probability distribution relate to the expected outcome of a random variable

# %% [markdown]
# ANS 21)Assumptions for Applying the CLT
# Sample size is sufficiently large (n ≥ 30 is typical).
#
# Samples are independent and identically distributed (i.i.d.)
#
# Population has finite variance

# %% [markdown]
# ANS 22)The expected value (E[X]) is the long-run average outcome:
#
# Discretre:-e(x)=summation Xi * p(xi)
# Continuous:
# 𝐸(x)=integrate x.f(x)dx

# %% [markdown]
# ANS 23)The probability distribution shows all possible values and their likelihoods, and the expected value summarizes what we’d expect on average over many trials.

# %% [markdown]
# PRACTICAL

# %% [markdown]
# 1) Write a Python program to generate a random variable and display its value
# 2) Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)
#  3)Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution
# 4) Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
#  5)Create a Poisson distribution and visualize it using Python
#  6)Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution
#  7)Generate a continuous uniform distribution using NumPy and visualize it
# 8) Simulate data from a normal distribution and plot its histogram
# 9) Write a Python function to calculate Z-scores from a dataset and plot them
#  10)Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

# %%
#ANS 1)
import numpy as np

# Generate a random variable from a normal distribution
random_var = np.random.normal(loc=0, scale=1)
print(f"Random variable value: {random_var}")

# %%
#ANS 2)
import matplotlib.pyplot as plt
from scipy.stats import randint

# Discrete uniform from 1 to 6 (like a die)
x = np.arange(1, 7)
pmf = randint.pmf(x, 1, 7)

plt.bar(x, pmf)
plt.title("PMF of Discrete Uniform Distribution (1–6)")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e0b0e3d421c> in <cell line: 0>()
#       3
#       4 # Discrete uniform from 1 to 6 (like a die)
# ----> 5 x = np.arange(1, 7)
#       6 pmf = randint.pmf(x, 1, 7)
#       7
#
# NameError: name 'np' is not defined

# %%
#ANS 3)
from scipy.stats import bernoulli

def bernoulli_pdf(p, x):
    return bernoulli.pmf(x, p)

# Example usage
p = 0.6
for x in [0, 1]:
    print(f"P(X={x}) = {bernoulli_pdf(p, x)}")

# %%
#ANS 4)
from scipy.stats import binom

data = binom.rvs(n=10, p=0.5, size=1000)
plt.hist(data, bins=np.arange(12) - 0.5, edgecolor='black', density=True)
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of successes")
plt.ylabel("Frequency")
plt.show()

# %%
#ANS 5)
from scipy.stats import poisson

mu = 3  # mean number of events
x = np.arange(0, 10)
pmf = poisson.pmf(x, mu)

plt.bar(x, pmf)
plt.title("Poisson Distribution (λ = 3)")
plt.xlabel("Number of events")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %%
#ANS 6)
cdf = randint.cdf(x, 1, 7)

plt.step(x, cdf, where='mid')
plt.title("CDF of Discrete Uniform Distribution (1–6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %%
#ANS 7)
from scipy.stats import uniform

data = uniform.rvs(loc=0, scale=1, size=1000)

plt.hist(data, bins=20, edgecolor='black', density=True)
plt.title("Continuous Uniform Distribution (0 to 1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
#ANS 8)
data = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(data, bins=30, edgecolor='black', density=True)
plt.title("Normal Distribution Histogram")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
#ANS 9)
import seaborn as sns

def compute_z_scores(data):
    mean = np.mean(data)
    std = np.std(data)
    return (data - mean) / std

data = np.random.normal(50, 10, 100)
z_scores = compute_z_scores(data)

sns.histplot(z_scores, bins=20, kde=True)
plt.title("Z-scores of Sample Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.show()

# %%
#ANS 10)
sample_means = []
for _ in range(1000):
    sample = np.random.exponential(scale=2, size=30)  # non-normal source
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, edgecolor='black', density=True)
plt.title("Central Limit Theorem: Sample Means (Exponential Source)")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #ANS 11)
#
#
# Mean (μ) = 0
#
# Standard deviation (σ) = 1
#
# This bell-shaped curve is symmetrical around zero and is the basis for calculating Z-scores, confidence intervals, and performing hypothesis tests in standard form.

# %%
#ans 12)

import numpy as np
from scipy.stats import norm

def calculate_z_score(x, mean, std):
    z = (x - mean) / std
    probability = norm.cdf(z)

    print(f"Data Point: {x}")
    print(f"Mean: {mean}, Standard Deviation: {std}")
     print(f"Z-score: {z:.4f}")
    print(f"Probability that a value is ≤ {x} (P(Z ≤ {z:.2f})): {probability:.4f}")

# %%
#ans 13)
import numpy as np
from scipy.stats import norm

def z_test(sample_data, population_mean, population_std, alpha=0.05):
    n = len(sample_data)
    sample_mean = np.mean(sample_data)

    # Calculate Z-statistic
    z = (sample_mean - population_mean) / (population_std / np.sqrt(n))

    # Two-tailed test: calculate p-value
    p_value = 2 * (1 - norm.cdf(abs(z)))

    print(f"Sample Mean = {sample_mean:.2f}")
    print(f"Z-statistic = {z:.4f}")
    print(f"P-value = {p_value:.4f}")

    if p_value < alpha:
        print("Result: Reject the null hypothesis (statistically significant).")
    else:
        print("Result: Fail to reject the null hypothesis (not statistically significant).")

# %%
#ans 14)
import numpy as np
from scipy.stats import norm

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std = np.std(data, ddof=1)  # sample standard deviation
    z_critical = norm.ppf((1 + confidence) / 2)  # Z-score for desired confidence level

    margin_of_error = z_critical * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    print(f"Sample Mean: {mean:.2f}")
    print(f"Confidence Interval ({int(confidence*100)}%): [{lower_bound:.2f}, {upper_bound:.2f}]")
    return lower_bound, upper_bound

# %%
#ans 15)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mu = 0      # mean
sigma = 1   # standard deviation

# Generate x values (range of values)
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# Compute the PDF
pdf = norm.pdf(x, mu, sigma)

# Plot the PDF
plt.figure(figsize=(8, 5))
plt.plot(x, pdf, label=f'N({mu}, {sigma}²)', color='blue')
plt.title('Probability Density Function of a Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.show()

# %%
#ans 16)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameter for the Poisson distribution (average rate λ)
lambda_ = 5

# Generate x values (possible event counts)
x = np.arange(0, 15)

# Calculate the CDF for each value of x
cdf = poisson.cdf(x, lambda_)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='post', label=f'Poisson CDF (λ={lambda_})', color='green')
plt.title('Cumulative Distribution Function of a Poisson Distribution')
plt.xlabel('Number of Events')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.legend()
plt.show()

# %%
#ans 17)
import numpy as np

# Parameters for the uniform distribution
a = 0   # Lower bound
b = 10  # Upper bound

# Simulate 1000 random variables from a continuous uniform distribution
random_variables = np.random.uniform(a, b, 1000)

# Calculate the expected value (mean) from the simulated data
expected_value_simulated = np.mean(random_variables)

# Calculate the theoretical expected value
expected_value_theoretical = (a + b) / 2

# Display results
expected_value_simulated, expected_value_theoretical

# %%
#ans 18)
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
# Dataset 1: Standard deviation = 3
data1 = np.random.normal(loc=50, scale=3, size=500)

# Dataset 2: Standard deviation = 8
data2 = np.random.normal(loc=50, scale=8, size=500)

# Calculate the standard deviations
std_dev_data1 = np.std(data1)
std_dev_data2 = np.std(data2)

# Print the standard deviations
print(f"Standard Deviation of Dataset 1: {std_dev_data1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev_data2:.2f}")

# Visualize the difference using histograms
plt.figure(figsize=(10, 6))

# Plot histogram for Dataset 1
plt.hist(data1, bins=30, alpha=0.5, label=f'Dataset 1 (σ={std_dev_data1:.2f})', color='blue')

# Plot histogram for Dataset 2
plt.hist(data2, bins=30, alpha=0.5, label=f'Dataset 2 (σ={std_dev_data2:.2f})', color='orange')

# Add title and labels
plt.title('Comparison of Standard Deviations of Two Datasets')
plt.xlabel('Data Values')
plt.ylabel('Frequency')

# Add a legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
#ans 19)
import numpy as np
import matplotlib.pyplot as plt

# Generate two datasets
# Dataset 1: Standard deviation = 3
data1 = np.random.normal(loc=50, scale=3, size=500)

# Dataset 2: Standard deviation = 8
data2 = np.random.normal(loc=50, scale=8, size=500)

# Calculate the standard deviations
std_dev_data1 = np.std(data1)
std_dev_data2 = np.std(data2)

# Print the standard deviations
print(f"Standard Deviation of Dataset 1: {std_dev_data1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev_data2:.2f}")

# Visualize the difference using histograms
plt.figure(figsize=(10, 6))

# Plot histogram for Dataset 1
plt.hist(data1, bins=30, alpha=0.5, label=f'Dataset 1 (σ={std_dev_data1:.2f})', color='blue')

# Plot histogram for Dataset 2
plt.hist(data2, bins=30, alpha=0.5, label=f'Dataset 2 (σ={std_dev_data2:.2f})', color='orange')

# Add title and labels
plt.title('Comparison of Standard Deviations of Two Datasets')
plt.xlabel('Data Values')
plt.ylabel('Frequency')

# Add a legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
